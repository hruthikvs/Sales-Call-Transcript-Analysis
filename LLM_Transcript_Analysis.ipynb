# %%
from google import genai
from google.genai import types

def call_gemini_api(prompt):



    sys_instruct="You are an AI assistant that analyzes sales call transcripts."
    client = genai.Client(api_key="AIzaSyBQOcdllktpU558z-KNV0ONHSbirqdKAyE")

    response = client.models.generate_content(
        model="gemini-2.0-flash",
        config=types.GenerateContentConfig(
            system_instruction=sys_instruct),
        contents=[f"{prompt}"]
    )



    return response.text

def evaluate_transcript(transcript, framework):
    prompt = f"""
    Analyze the following sales call transcript and provide a score (0-2) for each of the following categories:

    1. Ideal Customer Profile (ICP) Fitment
    2. Needs & Deal Completion Timing
    3. Budget & Authority

    Our Framework Details:

    {framework}

    Provide a justification for each score in a structured format.

    Below you can find the transcript to analyse
    Transcript:

    {transcript}


    Return the response in this format:
    ICP Fitment: X/2 - Justification\nNeeds Timing: X/2 - Justification\nBudget & Authority: X/2 - Justification
    """

    result = call_gemini_api(prompt)
    print(result)

# %%
from google.colab import files

# Upload the file
uploaded = files.upload()


prompt_file_path = 'PepSalesPrompts.txt'

# Read the content of the file
with open(prompt_file_path, 'r') as file:
    sample_transcript = file.read()

framework_file_path = 'PepSalesFramework.txt'

# Read the content of the file
with open(prompt_file_path, 'r') as file:
    framework = file.read()
# Out:
#      <input type="file" id="files-a9bd6bf6-117d-43dd-96de-b27024f75f42" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a9bd6bf6-117d-43dd-96de-b27024f75f42">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Output 1
evaluate_transcript(sample_transcript,framework )
# Out:
# Here's an analysis of the sales call transcript, broken down by the requested categories:
#
# **ICP Fitment: 2/2** - Justification: The prospect, Milano, represents a motor group in the UK and was referred by a key industry contact (Simon from Nxt). They have a current need for improved vehicle visuals, as they are not fully utilizing 360° imagery on their website despite having the equipment. They are actively selling cars and listing them on Autotrader, indicating a desire to enhance their online presence. The products offered align well with the prospect's business and the initial conversation suggests a good fit for Spine's solutions.
#
# ...

# %%
# Output 2
# With Transcript 2
uploaded = files.upload()


prompt_file_path = 'HRSoftwareSalesCall.txt'

# Read the content of the file
with open(prompt_file_path, 'r') as file:
    sample_transcript = file.read()

# Now `text` contains the content of the file as a string
evaluate_transcript(sample_transcript, framework)
# Out:
#      <input type="file" id="files-2e7659bd-de3c-42ea-b56a-7626ebf489e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2e7659bd-de3c-42ea-b56a-7626ebf489e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
